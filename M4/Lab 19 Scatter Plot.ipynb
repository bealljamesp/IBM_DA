# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Scatter Plot**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# ## Overview
#
# In this lab, you will focus on creating and interpreting scatter plots to visualize relationships between variables and trends in the dataset. The provided dataset will be directly loaded into a pandas DataFrame, and various scatter plot-related visualizations will be created to explore developer trends, compensation, and preferences.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will:
#
# - Create and analyze scatter plots to examine relationships between variables.
#
# - Use scatter plots to identify trends and patterns in the dataset.
#
# - Focus on visualizations centered on scatter plots for better data-driven insights.

# %% [markdown]
# ## Setup: Working with the Database

# %% [markdown]
# **Install and import the required libraries**

# %%
# !pip install pandas
# !pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Step 1: Load the dataset

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

df = pd.read_csv(file_path)

# %% [markdown]
# ### Task 1: Exploring Relationships with Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot for Age vs. Job Satisfaction

# %% [markdown]
# Visualize the relationship between respondents' age (`Age`) and job satisfaction (`JobSatPoints_6`). Use this plot to identify any patterns or trends.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Clean the data (replace with your actual DataFrame name)
df = df.copy()

# Optional: Map Age categories to numeric values (if not already numeric)
age_map = {
    'Under 18 years old': 16,
    '18-24 years old': 21,
    '25-34 years old': 29,
    '35-44 years old': 39,
    '45-54 years old': 49,
    '55-64 years old': 59,
    '65 years or older': 70,
    'Prefer not to say': None
}
df['AgeNumeric'] = df['Age'].map(age_map)

# Step 2: Drop missing values
df_clean = df.dropna(subset=['AgeNumeric', 'JobSatPoints_6'])

# Step 3: Create scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_clean, x='AgeNumeric', y='JobSatPoints_6', alpha=0.6)
plt.title('Scatter Plot: Age vs Job Satisfaction')
plt.xlabel('Age (Approximate)')
plt.ylabel('Job Satisfaction (1 = Very dissatisfied, 6 = Very satisfied)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Compensation vs. Job Satisfaction

# %% [markdown]
# Explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`) using a scatter plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Clean the data (replace df with your actual DataFrame name)
df_clean = df.copy()

# Step 2: Convert compensation to numeric if needed
df_clean['ConvertedCompYearly'] = pd.to_numeric(df_clean['ConvertedCompYearly'], errors='coerce')

# Step 3: Drop missing values in relevant columns
df_clean = df_clean.dropna(subset=['ConvertedCompYearly', 'JobSatPoints_6'])

# Optional: Remove extreme outliers (e.g., top 1%) for clearer visualization
q99 = df_clean['ConvertedCompYearly'].quantile(0.99)
df_filtered = df_clean[df_clean['ConvertedCompYearly'] <= q99]

# Step 4: Plot the scatter plot
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_filtered, x='ConvertedCompYearly', y='JobSatPoints_6', alpha=0.5)
plt.title('Scatter Plot: Yearly Compensation vs Job Satisfaction')
plt.xlabel('Converted Compensation (Yearly)')
plt.ylabel('Job Satisfaction (1 = Very dissatisfied, 6 = Very satisfied)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 2: Enhancing Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot with Trend Line for Age vs. Job Satisfaction

# %% [markdown]
# Add a regression line to the scatter plot of Age vs. JobSatPoints_6 to highlight trends in the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Map age categories to numeric values (if necessary)
age_map = {
    'Under 18 years old': 16,
    '18-24 years old': 21,
    '25-34 years old': 29,
    '35-44 years old': 39,
    '45-54 years old': 49,
    '55-64 years old': 59,
    '65 years or older': 70,
    'Prefer not to say': None
}
df['AgeNumeric'] = df['Age'].map(age_map)

# Step 2: Drop missing values for relevant columns
df_clean = df.dropna(subset=['AgeNumeric', 'JobSatPoints_6'])

# Step 3: Create scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.regplot(
    data=df_clean,
    x='AgeNumeric',
    y='JobSatPoints_6',
    scatter_kws={'alpha': 0.5},
    line_kws={'color': 'red', 'lw': 2}
)
plt.title('Age vs Job Satisfaction with Regression Line')
plt.xlabel('Age (Approximate)')
plt.ylabel('Job Satisfaction (1 = Very dissatisfied, 6 = Very satisfied)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Age vs. Work Experience

# %% [markdown]
# Visualize the relationship between Age (`Age`) and Work Experience (`YearsCodePro`) using a scatter plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Map Age to numeric values (if needed)
age_map = {
    'Under 18 years old': 16,
    '18-24 years old': 21,
    '25-34 years old': 29,
    '35-44 years old': 39,
    '45-54 years old': 49,
    '55-64 years old': 59,
    '65 years or older': 70,
    'Prefer not to say': None
}
df['AgeNumeric'] = df['Age'].map(age_map)

# Step 2: Convert YearsCodePro to numeric
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')

# Step 3: Drop missing values
df_clean = df.dropna(subset=['AgeNumeric', 'YearsCodePro'])

# Step 4: Plot the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_clean, x='AgeNumeric', y='YearsCodePro', alpha=0.6)
plt.title('Scatter Plot: Age vs Professional Coding Experience')
plt.xlabel('Age (Approximate)')
plt.ylabel('Years of Professional Coding Experience')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3: Combining Scatter Plots with Additional Features

# %% [markdown]
# #### 1. Bubble Plot of Compensation vs. Job Satisfaction with Age as Bubble Size

# %% [markdown]
# Create a bubble plot to explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), with bubble size representing age.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Map Age to numeric values
age_map = {
    'Under 18 years old': 16,
    '18-24 years old': 21,
    '25-34 years old': 29,
    '35-44 years old': 39,
    '45-54 years old': 49,
    '55-64 years old': 59,
    '65 years or older': 70,
    'Prefer not to say': None
}
df['AgeNumeric'] = df['Age'].map(age_map)

# Step 2: Convert compensation to numeric
df['ConvertedCompYearly'] = pd.to_numeric(df['ConvertedCompYearly'], errors='coerce')

# Step 3: Drop missing values
df_clean = df.dropna(subset=['ConvertedCompYearly', 'JobSatPoints_6', 'AgeNumeric'])

# Optional: Cap compensation at 99th percentile to reduce skew
q99 = df_clean['ConvertedCompYearly'].quantile(0.99)
df_filtered = df_clean[df_clean['ConvertedCompYearly'] <= q99]

# Step 4: Create bubble plot
plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=df_filtered,
    x='ConvertedCompYearly',
    y='JobSatPoints_6',
    size='AgeNumeric',
    sizes=(20, 300),
    alpha=0.6,
    palette='viridis',
    hue='AgeNumeric',  # optional color gradient by age
    legend='brief'
)
plt.title('Bubble Plot: Compensation vs Job Satisfaction (Bubble Size = Age)')
plt.xlabel('Yearly Compensation (ConvertedCompYearly)')
plt.ylabel('Job Satisfaction (1 = Very dissatisfied, 6 = Very satisfied)')
plt.grid(True)
plt.tight_layout()
plt.legend(title='Age (Bubble Size)')
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Popular Programming Languages by Job Satisfaction

# %% [markdown]
# Visualize the popularity of programming languages (`LanguageHaveWorkedWith`) against job satisfaction using a scatter plot. Use points to represent satisfaction levels for each language.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Drop missing values
df_clean = df.dropna(subset=['LanguageHaveWorkedWith', 'JobSatPoints_6'])

# Step 2: Split multiple languages into lists
df_clean['LanguageList'] = df_clean['LanguageHaveWorkedWith'].str.split(';')

# Step 3: Explode into multiple rows per language
df_exploded = df_clean.explode('LanguageList')

# Step 4: Group by language and calculate average job satisfaction
lang_satisfaction = (
    df_exploded.groupby('LanguageList')['JobSatPoints_6']
    .mean()
    .reset_index()
    .rename(columns={'LanguageList': 'Language', 'JobSatPoints_6': 'AvgJobSat'})
)

# Optional: Sort by popularity (count)
lang_counts = df_exploded['LanguageList'].value_counts().reset_index()
lang_counts.columns = ['Language', 'Count']

# Merge counts with satisfaction
lang_summary = pd.merge(lang_satisfaction, lang_counts, on='Language')

# Step 5: Plot scatter plot
plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=lang_summary,
    x='Count',  # Popularity
    y='AvgJobSat',  # Average Job Satisfaction
    hue='Language',  # Optional for color
    palette='tab20',
    legend=False,
    s=100
)
plt.title('Programming Language Popularity vs. Average Job Satisfaction')
plt.xlabel('Number of Respondents Who Have Worked With Language')
plt.ylabel('Average Job Satisfaction (1–6)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\beall\AppData\Local\Temp\ipykernel_6876\1547099521.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['LanguageList'] = df_clean['LanguageHaveWorkedWith'].str.split(';')

# %% [markdown]
# ### Task 4: Scatter Plot Comparisons Across Groups

# %% [markdown]
# #### 1. Scatter Plot for Compensation vs. Job Satisfaction by Employment Type

# %% [markdown]
# Visualize the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), categorized by employment type (`Employment`). Use color coding or markers to differentiate between employment types.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Clean and prepare the data
df['ConvertedCompYearly'] = pd.to_numeric(df['ConvertedCompYearly'], errors='coerce')
df_clean = df.dropna(subset=['ConvertedCompYearly', 'JobSatPoints_6', 'Employment'])

# Optional: Cap extremely high compensation values (e.g., top 1%)
q99 = df_clean['ConvertedCompYearly'].quantile(0.99)
df_filtered = df_clean[df_clean['ConvertedCompYearly'] <= q99]

# Step 2: Plot with color-coded employment types
plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=df_filtered,
    x='ConvertedCompYearly',
    y='JobSatPoints_6',
    hue='Employment',
    alpha=0.6,
    style='Employment',  # Optional: different marker shapes
    palette='Set2'
)

# Step 3: Customize plot
plt.title('Compensation vs. Job Satisfaction by Employment Type')
plt.xlabel('Yearly Compensation (ConvertedCompYearly)')
plt.ylabel('Job Satisfaction (1 = Very Dissatisfied, 6 = Very Satisfied)')
plt.grid(True)
plt.legend(title='Employment Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\beall\AppData\Local\Temp\ipykernel_6876\3272875939.py:31: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# #### 2. Scatter Plot for Work Experience vs. Age Group by Country

# %% [markdown]
# Compare work experience (`YearsCodePro`) across different age groups (`Age`) and countries (`Country`). Use colors to represent different countries and markers for age groups.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Clean and convert relevant columns
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')
df_clean = df.dropna(subset=['YearsCodePro', 'Age', 'Country'])

# Optional: Limit to top N countries for readability
top_countries = df_clean['Country'].value_counts().nlargest(5).index
df_filtered = df_clean[df_clean['Country'].isin(top_countries)]

# Optional: Simplify Age categories if needed (already strings)
# Example: You can sort them logically if you want (optional)

# Step 2: Create the plot
plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=df_filtered,
    x='Age',
    y='YearsCodePro',
    hue='Country',       # Color by country
    style='Age',         # Marker shape by age group
    palette='Set2',
    alpha=0.6
)

# Step 3: Customize the plot
plt.title('Professional Work Experience by Age Group and Country')
plt.xlabel('Age Group')
plt.ylabel('Years of Professional Coding Experience')
plt.xticks(rotation=15)
plt.legend(title='Country / Age Group', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Final Step: Review

# %% [markdown]
# With these scatter plots, you will have analyzed data relationships across multiple dimensions, including compensation, job satisfaction, employment types, and demographics, to uncover meaningful trends in the developer community.

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Analyze how numerical variables relate across specific groups, such as employment types and countries.
# - Use scatter plots effectively to represent multiple variables with color, size, and markers.
# - Gain insights into compensation, satisfaction, and demographic trends using advanced scatter plot techniques.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-07|1.2|Madhusudan Moole|Reviewed and updated lab|
# |2024-10-06|1.0|Raghul Ramesh|Created lab|-->

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
